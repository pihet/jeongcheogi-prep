# %% [markdown]
# # 암기노트 객관식 퀴즈
#
# > `자료/암기노트_약어정리.ipynb` 의 7개 대단원을 그대로 따라간 **4지선다 객관식** 문제은행입니다.
# > 맨땅에 답을 적는 게 아직 부담스러울 때, **먼저 이걸로 감을 잡고** 나중에 단답형으로 넘어가세요.
#
# **규칙**
# 1. ①~④ 중 하나를 고르고, 정답 토글을 열기 전에 **번호를 빈 셀에 적는다.**
# 2. 오답 보기도 전부 실제로 헷갈리는 개념에서 뽑았다. 왜 틀렸는지 해설까지 읽을 것.
# 3. 이 퀴즈에서 8할 이상 맞으면 → 암기노트 단답형(`자료` 폴더에 없다면 `문제은행/05_단답형_문제은행.ipynb`)으로 넘어갈 것.
#
# **총 79문항** (섹션 7개)
#
# ---

# %% [markdown]
# ## 1. 네트워크 (11문항)
#
# ---

# %% [markdown]
# ### 1 Q1.
#
# OSI 7계층 중 IP, ICMP, ARP가 속한 계층은?
#
# ① 데이터링크 계층
# ② 네트워크 계층
# ③ 전송 계층
# ④ 세션 계층

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 네트워크 계층**
#
# IP·ICMP·ARP·RARP·IGMP는 3계층(네트워크)이다. 2계층(데이터링크)은 HDLC·PPP·MAC, 4계층(전송)은 TCP·UDP다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q2.
#
# IP 주소를 물리적 MAC 주소로 변환하는 프로토콜은?
#
# ① RARP
# ② ARP
# ③ ICMP
# ④ DHCP

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② ARP**
#
# ARP는 IP→MAC 변환, 반대로 MAC→IP 변환은 RARP다. 방향을 헷갈리기 쉽다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q3.
#
# TCP 연결 설정(3-way handshake)의 올바른 순서는?
#
# ① ACK → SYN → SYN+ACK
# ② SYN → SYN+ACK → ACK
# ③ SYN → ACK → SYN+ACK
# ④ SYN+ACK → SYN → ACK

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② SYN → SYN+ACK → ACK**
#
# 연결은 SYN → SYN+ACK → ACK, 해제(4-way)는 FIN → ACK → FIN → ACK 순서다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q4.
#
# IP 주소 클래스 C의 기본 서브넷 마스크는?
#
# ① 255.0.0.0
# ② 255.255.0.0
# ③ 255.255.255.0
# ④ 255.255.255.192

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 255.255.255.0**
#
# 클래스 A는 /8, B는 /16, C는 /24(255.255.255.0)가 기본 마스크다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q5.
#
# IPv6 주소의 길이는?
#
# ① 32비트
# ② 64비트
# ③ 128비트
# ④ 256비트

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 128비트**
#
# IPv4는 32비트, IPv6는 128비트다. IPv6는 헤더 단순화, 보안 강화, QoS 지원을 위해 도입됐다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q6.
#
# 링크 상태(Link-State) 방식으로 동작하며 다익스트라 알고리즘을 사용하는 내부 라우팅 프로토콜은?
#
# ① RIP
# ② BGP
# ③ OSPF
# ④ ARP

# %%
1 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ OSPF**
#
# RIP는 거리 벡터(최대 15홉), OSPF는 링크 상태·다익스트라 — 둘 다 내부(IGP)다. BGP는 경로 벡터 방식의 외부(EGP) 프로토콜이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q7.
#
# HDLC 프레임 중 오류 제어·흐름 제어를 담당하며 RR, RNR, REJ 등이 속하는 것은?
#
# ① 정보(I) 프레임
# ② 감독(S) 프레임
# ③ 비번호(U) 프레임
# ④ 제어 프레임

# %%
4 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 감독(S) 프레임**
#
# 정보(I) 프레임은 사용자 데이터 전달, 감독(S) 프레임은 오류·흐름 제어, 비번호(U) 프레임은 링크 동작 모드 설정을 담당한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q8.
#
# HDLC 전송 모드 중, 균형 링크에서 혼합국끼리 허가 없이 언제나 전송할 수 있는 모드는?
#
# ① NRM
# ② ARM
# ③ ABM
# ④ SRM

# %%
2 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ ABM**
#
# NRM은 주국의 허가(Poll)가 필요, ABM은 균형 링크에서 자유롭게 전송, ARM은 불균형 링크에서 종국이 허가 없이 송신만 가능하다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q9.
#
# 서브넷 마스크 255.255.254.0의 프리픽스 비트 길이는?
#
# ① /22
# ② /23
# ③ /24
# ④ /25

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② /23**
#
# 255.255.254.0 = 8+8+7(254=11111110) = 23비트, 즉 /23이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q10.
#
# 네트워크 주소와 브로드캐스트 주소를 뺀 실제 호스트 수를 구하는 공식은?
#
# ① 2^(호스트비트)
# ② 2^(호스트비트) - 1
# ③ 2^(호스트비트) - 2
# ④ 2^(32-호스트비트)

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 2^(호스트비트) - 2**
#
# 호스트 비트가 h개면 2^h개의 주소가 나오는데, 맨 앞(네트워크 주소)과 맨 뒤(브로드캐스트 주소)를 빼야 하므로 2^h - 2다.
#
# </details>
#
# ---

# %% [markdown]
# ### 1 Q11.
#
# 사설 IP와 공인 IP를 변환해주는 기술은?
#
# ① NAT
# ② DHCP
# ③ SNMP
# ④ IGMP

# %%
3 #1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① NAT**
#
# NAT(Network Address Translation)가 사설IP↔공인IP 변환을 담당한다. DHCP는 IP 자동 할당이다.
#
# </details>
#
# ---

# %% [markdown]
# ## 2. 운영체제 (10문항)
#
# ---

# %% [markdown]
# ### 2 Q1.
#
# HRN 스케줄링의 우선순위 계산 공식은?
#
# ① 서비스시간 / 대기시간
# ② (대기시간 + 서비스시간) / 서비스시간
# ③ 대기시간 - 서비스시간
# ④ 대기시간 / (대기시간 + 서비스시간)

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② (대기시간 + 서비스시간) / 서비스시간**
#
# HRN 우선순위 = (대기시간 + 서비스시간) / 서비스시간. 값이 클수록 먼저 실행되며, SJF의 무한 대기(기아) 문제를 보완한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q2.
#
# 다음 중 비선점형 스케줄링 알고리즘은?
#
# ① SRT
# ② 라운드 로빈(RR)
# ③ FCFS
# ④ 다단계 피드백 큐

# %%
#3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ FCFS**
#
# FCFS·SJF·HRN·우선순위는 비선점형, RR·SRT·다단계 피드백 큐는 선점형이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q3.
#
# 페이지 교체 알고리즘 중 프레임 수를 늘렸는데 오히려 페이지 부재가 늘어나는 벨레이디의 모순이 발생할 수 있는 것은?
#
# ① LRU
# ② OPT
# ③ FIFO
# ④ LFU

# %%
1 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ FIFO**
#
# FIFO는 프레임을 늘려도 페이지 부재가 늘어나는 벨레이디의 모순(Belady's Anomaly)이 발생할 수 있는 대표적인 알고리즘이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q4.
#
# 교착상태(Deadlock)의 발생 필요조건 4가지에 해당하지 않는 것은?
#
# ① 상호 배제
# ② 점유와 대기
# ③ 선점
# ④ 환형 대기

# %%
2 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 선점**
#
# 4가지 필요조건은 상호배제·점유와 대기·비선점(No Preemption)·환형대기다. '선점'이 아니라 '비선점'이 조건이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q5.
#
# 교착상태 회피(Avoidance) 기법의 대표적인 알고리즘은?
#
# ① 다익스트라 알고리즘
# ② 은행원 알고리즘
# ③ 그리디 알고리즘
# ④ 백트래킹

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 은행원 알고리즘**
#
# 은행원 알고리즘(Banker's Algorithm)이 교착상태 회피 기법의 대표다. 해결 기법은 예방·회피·발견·회복 4가지다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q6.
#
# 페이지 교체가 너무 잦아 처리 시간보다 교체 시간이 더 커지는 현상은?
#
# ① 워킹 셋
# ② 스래싱
# ③ 구역성
# ④ 페이지 폴트

# %%
4 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 스래싱**
#
# 스래싱(Thrashing)이다. 워킹 셋은 프로세스가 일정 시간 자주 참조하는 페이지 집합을 뜻한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q7.
#
# `chmod 754 file` 실행 시 '그룹'의 권한은?
#
# ① rwx
# ② r-x
# ③ r--
# ④ rw-

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② r-x**
#
# 7=rwx(소유자), 5=r-x(그룹), 4=r--(기타). 읽기4+쓰기2+실행1을 더한 값으로 해석한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q8.
#
# 패리티 없이 스트라이핑만 하며, 속도는 빠르지만 장애 시 데이터 복구가 불가능한 RAID 레벨은?
#
# ① RAID 0
# ② RAID 1
# ③ RAID 5
# ④ RAID 1+0

# %%
2 #1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① RAID 0**
#
# RAID 0(스트라이핑)은 패리티가 없어 속도는 빠르지만 장애 시 복구가 불가능하다. RAID 1은 미러링, RAID 5는 분산 패리티다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q9.
#
# 디스크 1개 장애까지 복구 가능하도록 데이터와 패리티를 여러 디스크에 분산 저장하는 RAID 레벨은?
#
# ① RAID 0
# ② RAID 1
# ③ RAID 5
# ④ RAID 2

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ RAID 5**
#
# RAID 5는 분산 패리티 방식으로, 디스크 1개 장애까지는 복구할 수 있다.
#
# </details>
#
# ---

# %% [markdown]
# ### 2 Q10.
#
# 라운드 로빈(RR) 스케줄링에서 각 프로세스가 CPU를 점유할 수 있는 최대 시간을 가리키는 용어는?
#
# ① 버스트 타임
# ② 타임 슬라이스(할당량, Quantum)
# ③ 대기 시간
# ④ 반환 시간

# %%
4 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 타임 슬라이스(할당량, Quantum)**
#
# 시간 할당량(Quantum, 타임 슬라이스)이 끝나면 프로세스는 무조건 준비 큐 맨 뒤로 이동한다.
#
# </details>
#
# ---

# %% [markdown]
# ## 3. 보안 (12문항)
#
# ---

# %% [markdown]
# ### 3 Q1.
#
# 정보보호의 3대 요소에 해당하지 않는 것은?
#
# ① 기밀성
# ② 무결성
# ③ 가용성
# ④ 신뢰성

# %%
4

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ④ 신뢰성**
#
# 3대 요소는 기밀성·무결성·가용성이다. 여기에 인증, 부인 방지가 확장 요소로 붙는다. '신뢰성'은 별개 개념이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q2.
#
# SEED와 ARIA의 공통점으로 옳은 것은?
#
# ① 국내에서 개발한 비대칭키 알고리즘이다
# ② 국내에서 개발한 대칭키 알고리즘이다
# ③ 해시 알고리즘이다
# ④ 미국에서 개발한 대칭키 알고리즘이다

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 국내에서 개발한 대칭키 알고리즘이다**
#
# SEED와 ARIA는 국내에서 개발한 대칭키(비밀키) 암호 알고리즘이라는 점이 자주 출제된다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q3.
#
# 사용자가 n명일 때 필요한 대칭키의 개수를 구하는 공식은?
#
# ① 2n
# ② n(n-1)/2
# ③ n^2
# ④ n-1

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② n(n-1)/2**
#
# 대칭키는 n(n-1)/2개, 비대칭키는 2n개가 필요하다. 대칭키가 키 분배는 어렵지만 속도는 빠르다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q4.
#
# 게시판 등에 악성 스크립트를 삽입해, 그 페이지를 보는 다른 사용자의 브라우저에서 스크립트가 실행되게 하는 공격은?
#
# ① SQL Injection
# ② CSRF
# ③ XSS
# ④ APT

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ XSS**
#
# XSS(Cross Site Scripting)는 다른 사용자의 브라우저에서 스크립트가 실행되는 것이 핵심이다. CSRF는 사용자 권한을 도용해 서버로 요청을 보내는 것이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q5.
#
# 출발지 IP와 목적지 IP를 동일하게 위조해 시스템이 자기 자신에게 응답하게 만드는 DoS 공격은?
#
# ① SYN Flooding
# ② Smurfing
# ③ Land Attack
# ④ Teardrop

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ Land Attack**
#
# Land Attack의 특징이다. Smurfing은 ICMP 브로드캐스트로 트래픽을 증폭시키는 공격이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q6.
#
# 데이터 소유자가 접근 권한을 직접 결정하는 접근 통제 방식은?
#
# ① DAC
# ② MAC
# ③ RBAC
# ④ ACL

# %%
2 #1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① DAC**
#
# DAC(Discretionary Access Control)는 소유자 기반, MAC(Mandatory)은 보안 등급 기반, RBAC는 역할 기반이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q7.
#
# 대상 조직이 자주 방문하는 웹사이트를 미리 감염시켜 두고 방문자를 노리는, 특정 집단을 표적으로 한 공격 기법은?
#
# ① Phishing
# ② Watering Hole
# ③ Pharming
# ④ Smishing

# %%
3 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Watering Hole**
#
# Watering Hole은 '특정 집단'을 노린다는 것이 핵심 판별 포인트다. Phishing은 불특정 다수를 노린다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q8.
#
# 레이스 컨디션 공격에서, 공격 대상 파일의 경로를 가리키도록 미리 만들어 두는 것은?
#
# ① 하드 링크
# ② 심볼릭 링크
# ③ 하이퍼 링크
# ④ 소프트 링크(존재하지 않는 용어)

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 심볼릭 링크**
#
# 심볼릭 링크는 경로(이름)를 가리키는 바로가기라 원본이 바뀌면 따라간다. 하드 링크는 inode를 직접 가리켜 이 공격에 쓰이지 않는다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q9.
#
# 조직의 정보보호 관리체계를 뜻하는 영문 약자는?
#
# ① ISO
# ② ISMS
# ③ PIMS
# ④ OWASP

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② ISMS**
#
# ISMS(Information Security Management System). 개인정보 보호까지 포함하면 ISMS-P다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q10.
#
# WEP의 취약점을 보완하기 위해 패킷마다 키를 동적으로 변경(키 믹싱)하고 메시지 무결성 검사(MIC)를 적용하는 무선랜 보안 프로토콜은?
#
# ① WPA2(CCMP/AES)
# ② WPA(TKIP)
# ③ WPA3
# ④ SSL

# %%
#2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② WPA(TKIP)**
#
# TKIP(임시 키 무결성 프로토콜)가 WPA에서 WEP의 취약점을 보완하기 위해 도입됐다. WPA2는 이후 AES 기반으로 더 강화됐다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q11.
#
# 침입을 탐지할 뿐 아니라 차단까지 수행하는 보안 솔루션은?
#
# ① IDS
# ② IPS
# ③ DMZ
# ④ VPN

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② IPS**
#
# IDS는 탐지만, IPS는 탐지 + 차단까지 수행한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 3 Q12.
#
# 취약점이 발견되었으나 아직 패치가 배포되기 전에 이루어지는 공격을 가리키는 용어는?
#
# ① APT
# ② Zero-Day
# ③ Rootkit
# ④ Backdoor

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Zero-Day**
#
# Zero-Day 공격이다. APT는 특정 대상을 장기간 지속적으로 공격하는 것을 가리킨다.
#
# </details>
#
# ---

# %% [markdown]
# ## 4. 소프트웨어 공학 (15문항)
#
# ---

# %% [markdown]
# ### 4 Q1.
#
# 나선형(Spiral) 모델의 올바른 반복 순서는?
#
# ① 개발 → 계획 → 위험분석 → 고객평가
# ② 계획 → 위험분석 → 개발 → 고객평가
# ③ 위험분석 → 계획 → 고객평가 → 개발
# ④ 계획 → 개발 → 위험분석 → 고객평가

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 계획 → 위험분석 → 개발 → 고객평가**
#
# 나선형 모델은 계획 → 위험 분석 → 개발 → 고객 평가를 반복하며 위험을 최소화한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q2.
#
# XP(eXtreme Programming)의 5가지 핵심 가치에 해당하지 않는 것은?
#
# ① 용기
# ② 단순성
# ③ 책임
# ④ 존중

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 책임**
#
# XP 5가치는 용기·단순성·의사소통·피드백·존중이다. '책임'은 포함되지 않는다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q3.
#
# 요구사항 개발 프로세스의 올바른 순서는?
#
# ① 분석 → 도출 → 명세 → 확인
# ② 도출 → 분석 → 명세 → 확인
# ③ 도출 → 명세 → 분석 → 확인
# ④ 확인 → 도출 → 분석 → 명세

# %%
1 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 도출 → 분석 → 명세 → 확인**
#
# 도출(Elicitation) → 분석(Analysis) → 명세(Specification) → 확인(Validation) 순서다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q4.
#
# DFD(자료 흐름도)에서 '자료 저장소'를 나타내는 기호는?
#
# ① 원
# ② 화살표
# ③ 이중선(평행선)
# ④ 사각형

# %%
4 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 이중선(평행선)**
#
# 프로세스=원, 자료 흐름=화살표, 자료 저장소=이중선, 단말(터미널)=사각형이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q5.
#
# SOLID 원칙 중 '개방-폐쇄 원칙'을 뜻하는 약어는?
#
# ① SRP
# ② OCP
# ③ LSP
# ④ DIP

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② OCP**
#
# OCP(Open-Closed Principle) = 확장에는 열려 있고 변경에는 닫혀 있어야 한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q6.
#
# GoF 디자인 패턴 23가지 중 '생성' 패턴의 개수는?
#
# ① 3개
# ② 5개
# ③ 7개
# ④ 11개

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 5개**
#
# 생성 5개, 구조 7개, 행위 11개로 합계 23개다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q7.
#
# 인스턴스가 오직 하나만 생성되도록 보장하는 디자인 패턴은?
#
# ① Factory Method
# ② Observer
# ③ Singleton
# ④ Adapter

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ Singleton**
#
# Singleton 패턴의 정의다. Factory Method는 객체 생성을 서브클래스에 위임하는 패턴이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q8.
#
# 모듈 간 결합도 중 가장 바람직하지 않은(나쁜) 것은?
#
# ① 자료 결합도
# ② 스탬프 결합도
# ③ 제어 결합도
# ④ 내용 결합도

# %%
#4

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ④ 내용 결합도**
#
# 결합도는 자료 → 스탬프 → 제어 → 외부 → 공통 → 내용 순으로 나빠진다. 내용 결합도가 가장 나쁘다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q9.
#
# 모듈 내 모든 기능이 단일한 목적을 수행하도록 구성된, 가장 바람직한 응집도는?
#
# ① 기능적 응집도
# ② 순차적 응집도
# ③ 시간적 응집도
# ④ 우연적 응집도

# %%
1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 기능적 응집도**
#
# 응집도는 기능적 → 순차적 → 교환적 → 절차적 → 시간적 → 논리적 → 우연적 순으로 나빠진다. 기능적이 가장 좋다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q10.
#
# 시스템을 데이터·화면·제어 세 부분으로 분리하는 아키텍처 패턴은?
#
# ① 파이프-필터
# ② MVC
# ③ 브로커
# ④ 계층화

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② MVC**
#
# MVC(Model-View-Controller) 패턴이다. 파이프-필터는 각 단계가 앞 단계의 출력을 입력으로 받는 방식이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q11.
#
# COCOMO 개발 유형 중 5만 라인 이하의 소규모·사무 처리용 프로그램에 해당하는 유형은?
#
# ① 조직형(Organic)
# ② 반분리형(Semi-detached)
# ③ 내장형(Embedded)
# ④ 혼합형

# %%
1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 조직형(Organic)**
#
# 조직형은 5만 라인 이하, 반분리형은 30만 라인 이하, 내장형은 30만 라인 초과다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q12.
#
# "윈도우·리눅스·macOS에서 모두 동작해야 한다"는 요구사항이 해당하는 비기능적 요구사항 유형은?
#
# ① 성능
# ② 자원
# ③ 운영
# ④ 보안

# %%
2 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 운영**
#
# 운영 = 어떤 환경(OS·플랫폼)에서 돌아가야 하는가. 자원은 하드웨어 사양(메모리·그래픽카드 등)을 뜻한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q13.
#
# 페이지 전체를 새로고침하지 않고 필요한 데이터만 비동기로 서버에 요청해 화면 일부만 갱신하는 기법은?
#
# ① REST
# ② WebSocket
# ③ AJAX
# ④ GraphQL

# %%
1 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ AJAX**
#
# AJAX(Asynchronous JavaScript and XML)의 정의다. REST는 API 설계 방식으로 AJAX와는 다른 개념이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q14.
#
# 입력 장치 없이 음성·동작·표정 등 자연스러운 표현으로 컴퓨터와 상호작용하는 UI 유형은?
#
# ① CLI
# ② GUI
# ③ NUI
# ④ OUI

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ NUI**
#
# NUI(Natural UI)의 정의다. OUI는 사물의 형태 자체가 인터페이스가 되는 방식이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 4 Q15.
#
# 소프트웨어 형상 관리 절차의 올바른 순서는?
#
# ① 통제 → 식별 → 감사 → 기록
# ② 식별 → 통제 → 감사 → 기록
# ③ 식별 → 감사 → 통제 → 기록
# ④ 감사 → 식별 → 통제 → 기록

# %%
3 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 식별 → 통제 → 감사 → 기록**
#
# 형상 식별 → 형상 통제 → 형상 감사 → 형상 기록 순서다. 암기: '식 통 감 기'
#
# </details>
#
# ---

# %% [markdown]
# ## 5. 테스트 (10문항)
#
# ---

# %% [markdown]
# ### 5 Q1.
#
# 동일한 테스트 케이스를 반복하면 더 이상 새로운 결함을 찾지 못한다는 테스트 원리는?
#
# ① 결함 집중
# ② 살충제 패러독스
# ③ 오류-부재의 궤변
# ④ 정황 의존

# %%
1 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 살충제 패러독스**
#
# 살충제 패러독스(Pesticide Paradox)다. 결함 집중은 결함이 소수 모듈에 몰린다는 원리(파레토 법칙)다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q2.
#
# 다음 중 화이트박스 테스트 기법이 아닌 것은?
#
# ① 기본 경로 테스트
# ② 조건 커버리지
# ③ 동치 분할
# ④ 데이터 흐름 테스트

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 동치 분할**
#
# 동치 분할은 블랙박스(명세 기반) 테스트 기법이다. 화이트박스는 코드 구조를 보고 판단하는 기법들이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q3.
#
# 다음 중 블랙박스 테스트 기법이 아닌 것은?
#
# ① 경곗값 분석
# ② 원인-결과 그래프
# ③ 기본 경로 테스트
# ④ 결정 테이블

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 기본 경로 테스트**
#
# 기본 경로 테스트는 화이트박스(구조 기반) 기법이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q4.
#
# 테스트 레벨(V 모델)의 올바른 순서는?
#
# ① 단위 → 시스템 → 통합 → 인수
# ② 단위 → 통합 → 시스템 → 인수
# ③ 통합 → 단위 → 시스템 → 인수
# ④ 단위 → 통합 → 인수 → 시스템

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 단위 → 통합 → 시스템 → 인수**
#
# 단위(Unit) → 통합(Integration) → 시스템(System) → 인수(Acceptance) 순서다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q5.
#
# 하향식 통합 테스트에서 아직 개발되지 않은 하위 모듈을 대신하는 더미 모듈은?
#
# ① Stub
# ② Driver
# ③ Mock Server
# ④ Proxy

# %%
1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① Stub**
#
# 하향식은 Stub, 상향식은 Driver가 필요하다. '하'향식→아래(하위)가 없으니 Stub, '상'향식→위(상위)가 없으니 Driver로 외운다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q6.
#
# 상향식 통합 테스트에서 하위 모듈에 데이터를 입력하고 결과를 확인하기 위해 상위 모듈 역할을 대신하는 더미 모듈은?
#
# ① Stub
# ② Driver
# ③ Wrapper
# ④ Adapter

# %%
2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Driver**
#
# Driver는 상향식 통합 테스트에서 상위 모듈을 대신한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q7.
#
# McCabe 순환 복잡도 V(G)를 구하는 공식은? (E=간선 수, N=노드 수)
#
# ① E + N + 2
# ② E - N + 2
# ③ E - N - 2
# ④ E × N + 2

# %%
4 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② E - N + 2**
#
# V(G) = E - N + 2. 필요한 최소 테스트 케이스 수를 뜻하기도 한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q8.
#
# 프로그램을 실행하지 않고 코딩 표준 준수 여부·문법 오류·잠재적 결함을 검사하는 도구는?
#
# ① 정적 분석 도구
# ② 동적 분석 도구
# ③ 단위 테스트 프레임워크
# ④ 형상 관리 도구

# %%
3 #1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 정적 분석 도구**
#
# 정적 분석 도구(pmd, cppcheck, SonarQube 등)는 실행 없이 검사한다. 동적 분석 도구는 실행하면서 메모리 누수 등을 검사한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q9.
#
# 자바용 xUnit 계열의 오픈소스 단위 테스트 프레임워크로, `@Test` 애너테이션을 사용하는 것은?
#
# ① JUnit
# ② SonarQube
# ③ Selenium
# ④ Valgrind

# %%
1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① JUnit**
#
# JUnit이다. Valgrind는 동적 분석 도구, SonarQube는 정적 분석 도구다.
#
# </details>
#
# ---

# %% [markdown]
# ### 5 Q10.
#
# 개발자가 있는 통제된 환경에서 사용자가 수행하는 인수 테스트 방식은?
#
# ① 알파 테스트
# ② 베타 테스트
# ③ 회귀 테스트
# ④ 부하 테스트

# %%
2 #1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 알파 테스트**
#
# 알파 테스트는 통제된 환경(개발사 내부), 베타 테스트는 실제 사용자 환경에서 이루어진다.
#
# </details>
#
# ---

# %% [markdown]
# ## 6. 데이터베이스 (13문항)
#
# ---

# %% [markdown]
# ### 6 Q1.
#
# 모든 속성의 도메인이 원자값만 갖도록 하는 정규화 단계는?
#
# ① 1NF
# ② 2NF
# ③ 3NF
# ④ BCNF

# %%
1

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 1NF**
#
# 1NF의 조건이다. 2NF는 부분 함수 종속 제거, 3NF는 이행 함수 종속 제거, BCNF는 모든 결정자가 후보키여야 한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q2.
#
# 모든 결정자가 후보키가 되도록 하는 정규화 단계는?
#
# ① 2NF
# ② 3NF
# ③ BCNF
# ④ 4NF

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ BCNF**
#
# BCNF(보이스-코드 정규형)의 조건이다. 4NF는 다치 종속 제거다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q3.
#
# 트랜잭션 실행 중 다른 트랜잭션이 끼어들 수 없어야 한다는 ACID 특성은?
#
# ① 원자성
# ② 일관성
# ③ 격리성
# ④ 영속성

# %%
3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 격리성**
#
# 격리성(Isolation)이다. 원자성은 전부 실행되거나 전혀 실행되지 않음, 영속성은 완료된 결과가 영구히 반영됨을 뜻한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q4.
#
# 유일성은 만족하지만 최소성은 만족하지 않는 키는?
#
# ① 후보키
# ② 슈퍼키
# ③ 대체키
# ④ 외래키

# %%
1 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 슈퍼키**
#
# 슈퍼키는 유일성만, 후보키는 유일성과 최소성을 모두 만족한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q5.
#
# 순수 관계 연산자에 해당하지 않는 것은?
#
# ① SELECT
# ② PROJECT
# ③ UNION
# ④ DIVISION

# %%
1 #3

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ UNION**
#
# 순수 관계 연산자는 SELECT·PROJECT·JOIN·DIVISION이다. UNION은 일반 집합 연산자다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q6.
#
# 정규화가 되지 않은 릴레이션에서 발생하는 이상(Anomaly) 현상에 해당하지 않는 것은?
#
# ① 삽입 이상
# ② 삭제 이상
# ③ 갱신 이상
# ④ 탐색 이상

# %%
4

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ④ 탐색 이상**
#
# 이상 현상 3가지는 삽입·삭제·갱신 이상이다. '탐색 이상'은 존재하지 않는 용어다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q7.
#
# 데이터베이스 설계 절차 중 E-R 다이어그램을 작성하는 단계는?
#
# ① 요구사항 분석
# ② 개념적 설계
# ③ 논리적 설계
# ④ 물리적 설계

# %%
3 #2

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 개념적 설계**
#
# 개념적 설계 = E-R 다이어그램 작성. 논리적 설계는 테이블 구조 확정 + 정규화, 물리적 설계는 인덱스·저장 구조 결정이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q8.
#
# 데이터베이스 설계 절차 중 저장 구조·인덱스·접근 경로를 결정하는 단계는?
#
# ① 개념적 설계
# ② 논리적 설계
# ③ 물리적 설계
# ④ 구현

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ③ 물리적 설계**
#
# 물리적 설계 단계의 역할이다. 논리와 물리를 바꿔 쓰는 실수가 가장 흔하다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q9.
#
# 관계 데이터 모델에서 '레코드(Record)'에 해당하는 정식 용어는?
#
# ① Attribute
# ② Tuple
# ③ Domain
# ④ Relation

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Tuple**
#
# 튜플(Tuple)=레코드(행), 속성(Attribute)=필드(열), 릴레이션(Relation)=파일(테이블) 전체다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q10.
#
# 튜플(행)의 개수를 가리키는 용어는?
#
# ① Degree(차수)
# ② Cardinality(카디널리티)
# ③ Domain(도메인)
# ④ Attribute(속성)

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Cardinality(카디널리티)**
#
# 카디널리티 = 튜플(행)의 개수, 디그리/차수 = 속성(열)의 개수다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q11.
#
# 키 값과 주소 포인터를 쌍으로 둔 별도의 색인 구조를 사용해 검색 속도를 향상시키는 레코드 접근 방법은?
#
# ① 순차 접근
# ② 색인 순차 접근(ISAM)
# ③ 직접(해싱) 접근
# ④ 임의 접근

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 색인 순차 접근(ISAM)**
#
# 색인 순차 접근(ISAM)의 정의다. 직접(해싱) 접근은 해시 함수로 저장 위치를 바로 계산한다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q12.
#
# 트랜잭션의 시작(Start)은 있지만 완료(Commit) 기록이 없는 트랜잭션의 변경 내용을 모두 취소하는 회복 기법은?
#
# ① Redo
# ② Undo
# ③ Checkpoint
# ④ Shadow Paging

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② Undo**
#
# Undo는 커밋되지 않은 트랜잭션을 취소, Redo는 커밋된 트랜잭션을 재실행하는 기법이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 6 Q13.
#
# 병행 제어 기법에 해당하지 않는 것은?
#
# ① 로킹(Locking)
# ② 타임스탬프
# ③ 낙관적 검증
# ④ 검사점(Checkpoint)

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ④ 검사점(Checkpoint)**
#
# 로킹·타임스탬프·낙관적 검증·다중 버전은 병행 제어 기법이다. 검사점(Checkpoint)은 회복 기법이다.
#
# </details>
#
# ---

# %% [markdown]
# ## 7. 신기술 용어 (8문항)
#
# ---

# %% [markdown]
# ### 7 Q1.
#
# 현실 사물을 가상 공간에 동일하게 구현해 시뮬레이션하는 기술은?
#
# ① 디지털 트윈
# ② 메타버스
# ③ 블록체인
# ④ 엣지 컴퓨팅

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 디지털 트윈**
#
# 디지털 트윈의 정의다. 메타버스는 3차원 가상 세계 자체를 가리킨다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q2.
#
# 서버를 직접 관리하지 않고 함수 단위로 코드를 실행하는 클라우드 모델은?
#
# ① 엣지 컴퓨팅
# ② 서버리스(Serverless)
# ③ SDN
# ④ NFV

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 서버리스(Serverless)**
#
# 서버리스(FaaS, Function as a Service)의 정의다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q3.
#
# 하나의 애플리케이션을 독립적으로 배포·확장 가능한 작은 서비스들의 집합으로 구성하는 아키텍처는?
#
# ① 모놀리식 아키텍처
# ② MSA
# ③ 클라이언트-서버
# ④ 3계층 아키텍처

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② MSA**
#
# MSA(Microservice Architecture)다. 서비스별 독립 배포와 다른 기술 스택 선택이 가능한 것이 장점이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q4.
#
# 내부·외부를 막론하고 아무것도 신뢰하지 않고 항상 검증하는 보안 모델은?
#
# ① 방화벽
# ② 제로 트러스트
# ③ DMZ
# ④ VPN

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 제로 트러스트**
#
# 제로 트러스트(Zero Trust)의 정의다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q5.
#
# HDFS와 MapReduce를 기반으로 한 대용량 분산 처리 프레임워크는?
#
# ① 하둡(Hadoop)
# ② 쿠버네티스
# ③ 도커
# ④ NoSQL

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ① 하둡(Hadoop)**
#
# 하둡이다. 쿠버네티스는 컨테이너 오케스트레이션 도구다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q6.
#
# 제어부와 데이터부를 분리해 네트워크를 소프트웨어로 제어하는 기술은?
#
# ① NFV
# ② SDN
# ③ MSA
# ④ CDN

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② SDN**
#
# SDN(Software Defined Network)이다. NFV는 네트워크 기능 자체를 가상화하는 기술이다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q7.
#
# 다수의 컨테이너를 배포·관리하는 오케스트레이션 도구는?
#
# ① 도커(Docker)
# ② 쿠버네티스(Kubernetes)
# ③ Jenkins
# ④ Git

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② 쿠버네티스(Kubernetes)**
#
# 쿠버네티스다. 도커는 컨테이너 기반 가상화 플랫폼 자체를 가리킨다.
#
# </details>
#
# ---

# %% [markdown]
# ### 7 Q8.
#
# 대량의 데이터를 Drill-down, Roll-up, Slicing 등으로 다차원 분석하는 기술은?
#
# ① OLTP
# ② OLAP
# ③ 데이터 마이닝
# ④ RPA

# %% [markdown]
# <details>
# <summary><b>👉 정답 · 해설 보기</b></summary>
#
# **정답: ② OLAP**
#
# OLAP(다차원 데이터 분석)의 정의다. OLTP는 실시간 거래 처리를 가리킨다.
#
# </details>
#
# ---
